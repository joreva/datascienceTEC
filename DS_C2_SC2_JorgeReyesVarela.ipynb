# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Extraer la información del archivo

# %%
df = pd.read_csv('/content/country_vaccinations.csv')

# %% [markdown]
# Mostrar la estructura y tipos de datos de cada columna para identificar qué operaciones puedes realizar con cada una de ellas, asegurándote que las columnas con fechas sean del tipo datetime64.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86512 entries, 0 to 86511
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              86512 non-null  object
#  1   iso_code                             86512 non-null  object
#  2   date                                 86512 non-null  object
#  3   total_vaccinations                   43607 non-null  float64
#  4   people_vaccinated                    41294 non-null  float64
#  5   people_fully_vaccinated              38802 non-null  float64
#  6   daily_vaccinations_raw               35362 non-null  float64
#  7   daily_vaccinations                   86213 non-null  float64
#  8   total_vaccinations_per_hundred       43607 non-null  float64
#  9   people_vaccinated_per_hundred        41294 non-null  float64
#  10  people_fully_vaccinated_per_hundred  38802 non-null  float64
#  11  daily_vaccinations_per_million       86213 non-null  float64
#  12  vaccines                             86512 non-null  object
#  13  source_name                          86512 non-null  object
#  14  source_website                       86512 non-null  object
# dtypes: float64(9), object(6)
# memory usage: 9.9+ MB

# %%
df['date'] = pd.to_datetime(df['date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86512 entries, 0 to 86511
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              86512 non-null  object
#  1   iso_code                             86512 non-null  object
#  2   date                                 86512 non-null  datetime64[ns]
#  3   total_vaccinations                   43607 non-null  float64
#  4   people_vaccinated                    41294 non-null  float64
#  5   people_fully_vaccinated              38802 non-null  float64
#  6   daily_vaccinations_raw               35362 non-null  float64
#  7   daily_vaccinations                   86213 non-null  float64
#  8   total_vaccinations_per_hundred       43607 non-null  float64
#  9   people_vaccinated_per_hundred        41294 non-null  float64
#  10  people_fully_vaccinated_per_hundred  38802 non-null  float64
#  11  daily_vaccinations_per_million       86213 non-null  float64
#  12  vaccines                             86512 non-null  object
#  13  source_name                          86512 non-null  object
#  14  source_website                       86512 non-null  object
# dtypes: datetime64[ns](1), float64(9), object(5)
# memory usage: 9.9+ MB

# %% [markdown]
# Determinar la cantidad de vacunas aplicadas de cada compañía (con base en cómo lo reporta cada país en la columna vaccines, en otras palabras, agrupe por vaccines y realice la sumatoria).

# %%
df[['vaccines','total_vaccinations']].groupby('vaccines').sum()
# Out:
#                                                     total_vaccinations
# vaccines
# Abdala, Johnson&Johnson, Oxford/AstraZeneca, Pf...        1.784348e+08
# Abdala, Moderna, Oxford/AstraZeneca, Pfizer/Bio...        1.791450e+10
# Abdala, Sinopharm/Beijing, Sinovac, Soberana02,...        4.228568e+08
# Abdala, Soberana Plus, Soberana02                         6.405166e+09
# COVIran Barekat, Covaxin, FAKHRAVAC, Oxford/Ast...        1.069480e+10
# ...                                                                ...
# Pfizer/BioNTech, Sinovac, Turkovac                        3.392310e+10
# Pfizer/BioNTech, Sputnik V                                3.863380e+06
# QazVac, Sinopharm/Beijing, Sputnik V                      3.585429e+09
# Sinopharm/Beijing                                         3.080671e+07
# Sinopharm/Beijing, Sputnik V                              6.451243e+08
#
# [84 rows x 1 columns]

# %% [markdown]
# Obtener la cantidad de vacunas aplicadas en todo el mundo.

# %%
df['total_vaccinations'].sum()
# Out:
# 2002854013761.0

# %% [markdown]
# Calcular el promedio de vacunas aplicadas por país.

# %%
df[['country','total_vaccinations']].groupby('country').mean().round(2)
# Out:
#                    total_vaccinations
# country
# Afghanistan                2566117.96
# Albania                    1191695.42
# Algeria                    9956085.92
# Andorra                      58277.21
# Angola                     6074066.30
# ...                               ...
# Wales                      4132861.16
# Wallis and Futuna             9142.92
# Yemen                       479404.86
# Zambia                     1048483.87
# Zimbabwe                   4181618.25
#
# [223 rows x 1 columns]

# %% [markdown]
# Determinar la cantidad de vacunas aplicadas el día 29/01/21 en todo el mundo.

# %%
df[df['date'] == '2021-01-29']['total_vaccinations'].sum()
# Out:
# 82952931.0

# %% [markdown]
# Crear un dataframe nuevo denominado conDiferencias que contenga los datos originales y una columna derivada (diferencias) con las diferencias de aplicación entre las columnas daily_vaccionations y daily_vaccionations_raw.

# %%
conDiferencias = df
conDiferencias['daily_vaccinations_raw'].fillna(0,inplace=True)
conDiferencias['diferencia'] = conDiferencias['daily_vaccinations'] - conDiferencias['daily_vaccinations_raw']
conDiferencias.head()
# Out:
#        country iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG 2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     0.0                 NaN
# 1                      NaN                     0.0              1367.0
# 2                      NaN                     0.0              1367.0
# 3                      NaN                     0.0              1367.0
# 4                      NaN                     0.0              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
# 1                                  NaN                            34.0
# 2                                  NaN                            34.0
# 3                                  NaN                            34.0
# 4                                  NaN                            34.0
#
#                                             vaccines  \
# 0  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 1  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 2  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 3  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 4  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
#
#                  source_name            source_website  diferencia
# 0  World Health Organization  https://covid19.who.int/         NaN
# 1  World Health Organization  https://covid19.who.int/      1367.0
# 2  World Health Organization  https://covid19.who.int/      1367.0
# 3  World Health Organization  https://covid19.who.int/      1367.0
# 4  World Health Organization  https://covid19.who.int/      1367.0

# %% [markdown]
# Obtener el periodo de tiempo entre el registro con fecha más reciente y el registro con fecha más antigua.

# %%
df['date'].max() - df['date'].min()
# Out:
# Timedelta('482 days 00:00:00')

# %% [markdown]
# Crear un dataframe nuevo denominado conCantidad que contenga los datos originales y una columna derivada (canVac) con la cantidad de vacunas utilizadas cada día (usar la columna vaccines y separar por el carácter , ).

# %%
conCantidad = df
conCantidad['canvaccines'] = conCantidad['vaccines'].str.split(', ').str.len()
conCantidad.head()
# Out:
#        country iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG 2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     0.0                 NaN
# 1                      NaN                     0.0              1367.0
# 2                      NaN                     0.0              1367.0
# 3                      NaN                     0.0              1367.0
# 4                      NaN                     0.0              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  NaN                             NaN
# 1                                  NaN                            34.0
# 2                                  NaN                            34.0
# 3                                  NaN                            34.0
# 4                                  NaN                            34.0
#
#                                             vaccines  \
# 0  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 1  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 2  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 3  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
# 4  Johnson&Johnson, Oxford/AstraZeneca, Pfizer/Bi...
#
#                  source_name            source_website  diferencia  \
# 0  World Health Organization  https://covid19.who.int/         NaN
# 1  World Health Organization  https://covid19.who.int/      1367.0
# 2  World Health Organization  https://covid19.who.int/      1367.0
# 3  World Health Organization  https://covid19.who.int/      1367.0
# 4  World Health Organization  https://covid19.who.int/      1367.0
#
#    canvaccines
# 0            4
# 1            4
# 2            4
# 3            4
# 4            4

# %% [markdown]
# Generar un dataframe denominado antes20 con todos los registros que se hayan realizado antes del 20 de diciembre de 2020.

# %%
antes20 = df[df['date'] < '2020-12-20']
antes20['date'].max()
# Out:
# Timestamp('2020-12-19 00:00:00')

# %% [markdown]
# Obtener un dataframe denominado pfizer con todos los registros donde se haya utilizado la vacuna Pfizer.

# %%
pfizer = df[df['vaccines'].str.contains('Pfizer')]
pfizer['vaccines'].value_counts()
# Out:
# vaccines
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech                                                          7608
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech                                                                           6263
# Oxford/AstraZeneca, Pfizer/BioNTech                                                                                    4629
# Johnson&Johnson, Moderna, Novavax, Oxford/AstraZeneca, Pfizer/BioNTech                                                 3564
# Moderna, Pfizer/BioNTech                                                                                               2309
# Pfizer/BioNTech                                                                                                        2271
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V                                                      2041
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing                                                                 2030
# Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing                                                1911
# Johnson&Johnson, Moderna, Pfizer/BioNTech                                                                              1873
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, Sputnik V                                                                1679
# Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V                                     1614
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing                                       1612
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinovac                                                        1190
# Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech                                                                   1142
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac                                                 1140
# Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinovac, Sputnik V                            1127
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac                                                                           1056
# CanSino, Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac                                                                   885
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V                             880
# Johnson&Johnson, Pfizer/BioNTech                                                                                        827
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V                                              827
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinovac, Sputnik Light, Sputnik V     755
# Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac                                                           752
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinovac, Sputnik V                    751
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinovac, Sputnik V                                              740
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing                                                         734
# Johnson&Johnson, Moderna, Novavax, Pfizer/BioNTech                                                                      480
# CanSino, Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, Sputnik V                              461
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik Light, Sputnik V              456
# CanSino, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V                                     456
# Moderna, Pfizer/BioNTech, Sinopharm/Beijing, Sinovac                                                                    454
# Johnson&Johnson, Moderna, Novavax, Oxford/AstraZeneca, Pfizer/BioNTech, Sputnik V                                       449
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinopharm/Wuhan, Sputnik V                                      449
# Johnson&Johnson, Moderna, Novavax, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinovac                      442
# Pfizer/BioNTech, Sinovac, Turkovac                                                                                      441
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinovac                               428
# Pfizer/BioNTech, Sinopharm/Beijing                                                                                      414
# CanSino, Covaxin, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinovac, Sputnik V                   402
# CanSino, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinovac                                                399
# Pfizer/BioNTech, Sinovac                                                                                                399
# Covaxin, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinovac, Sputnik V                            397
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinovac                                                396
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sputnik V                                                                 394
# Oxford/AstraZeneca, Pfizer/BioNTech, Sputnik V                                                                          392
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sputnik V                                                391
# Abdala, Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Soberana02, Sputnik Light, Sputnik V                      390
# Pfizer/BioNTech, Sputnik V                                                                                              387
# Abdala, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V                                      381
# Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinovac, Sputnik Light, Sputnik V              377
# Medigen, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech                                                                   374
# Johnson&Johnson, Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sinovac                                        363
# Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V                                                                           362
# Covaxin, Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac                                         362
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, Sputnik Light, Sputnik V, ZF2001                                 348
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, Sputnik V                                                        311
# Johnson&Johnson, Pfizer/BioNTech, Sinopharm/Beijing                                                                     228
# Name: count, dtype: int64

# %% [markdown]
# Almacenar los dataframes generados (conDiferencias, conCantidad, antes20 y pfizer) en un archivo de Excel denominado resultadosReto.xlsx, donde cada dataframe ocupe una hoja diferente. Se recomienda ver la documentación de pd.ExcelWriter.

# %%
with pd.ExcelWriter('resultadosReto.xlsx') as writer:
  conDiferencias.to_excel(writer, sheet_name='conDiferencias')
  conCantidad.to_excel(writer, sheet_name='conCantidad')
  antes20.to_excel(writer, sheet_name='antes20')
  pfizer.to_excel(writer, sheet_name='pfizer')
